# %%
import pandas as pd
df=pd.read_csv('AppleStore.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0          id                                 track_name  \
# 7192       11081  1187617475                                      Kubik
# 7193       11082  1187682390                          VR Roller-Coaster
# 7194       11087  1187779532      Bret Michaels Emojis + Lyric Keyboard
# 7195       11089  1187838770  VR Roller Coaster World - Virtual Reality
# 7196       11097  1188375727               Escape the Sweet Shop Series
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 7192   126644224      USD   0.00               142                75
# 7193   120760320      USD   0.00                30                30
# 7194   111322112      USD   1.99                15                 0
# 7195    97235968      USD   0.00                85                32
# 7196    90898432      USD   0.00                 3                 3
#
#       user_rating  user_rating_ver     ver cont_rating prime_genre  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7197 non-null   int64
#  1   id                7197 non-null   int64
#  2   track_name        7197 non-null   object
#  3   size_bytes        7197 non-null   int64
#  4   currency          7197 non-null   object
#  5   price             7197 non-null   float64
#  6   rating_count_tot  7197 non-null   int64
#  7   rating_count_ver  7197 non-null   int64
#  8   user_rating       7197 non-null   float64
#  9   user_rating_ver   7197 non-null   float64
#  10  ver               7197 non-null   object
#  11  cont_rating       7197 non-null   object
#  12  prime_genre       7197 non-null   object
#  13  sup_devices.num   7197 non-null   int64
#  14  ipadSc_urls.num   7197 non-null   int64
#  15  lang.num          7197 non-null   int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0            id    size_bytes        price  \
# count   7197.000000  7.197000e+03  7.197000e+03  7197.000000
# mean    4759.069612  8.631310e+08  1.991345e+08     1.726218
# std     3093.625213  2.712368e+08  3.592069e+08     5.833006
# min        1.000000  2.816565e+08  5.898240e+05     0.000000
# 25%     2090.000000  6.000937e+08  4.692275e+07     0.000000
# 50%     4380.000000  9.781482e+08  9.715302e+07     0.000000
# 75%     7223.000000  1.082310e+09  1.819249e+08     1.990000
# max    11097.000000  1.188376e+09  4.025970e+09   299.990000
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# count      7.197000e+03       7197.000000  7197.000000      7197.000000
# mean       1.289291e+04        460.373906     3.526956         3.253578
# std        7.573941e+04       3920.455183     1.517948         1.809363
# min        0.000000e+00          0.000000     0.000000         0.000000
# ...

# %%
df['id'].is_unique
# Out:
# True

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
#Plotting histogram of Rating
df['user_rating'].plot(kind='hist')

plt.show()

# %% [markdown]
# #### Cleaning

# %%
# Count duplicates based on all columns
num_duplicates = df.duplicated().sum()
print(f"Number of duplicates based on all columns: {num_duplicates}")
# Out:
# Number of duplicates based on all columns: 0

# %% [markdown]
# #### Prime genre and user rating summary
#
# These findings can give insights into user preferences and can help developers to prioritize certain categories when designing and releasing new apps

# %%
# Create a pivot table that summarizes user_rating by prime_genre
genre_rating_pivot = df.pivot_table(values='user_rating', index='prime_genre')

# Sort the pivot table by mean user_rating in descending order
genre_rating_pivot_sorted = genre_rating_pivot.sort_values('user_rating', ascending=False)

# Print the results
print(genre_rating_pivot_sorted)
# Out:
#                    user_rating
# prime_genre
# Productivity          4.005618
# Music                 3.978261
# Photo & Video         3.800860
# Business              3.745614
# Health & Fitness      3.700000
# Games                 3.685008
# Weather               3.597222
# Shopping              3.540984
# Reference             3.453125
# Travel                3.376543
# Education             3.376380
# Medical               3.369565
# Utilities             3.278226
# Entertainment         3.246729
# Food & Drink          3.182540
# Social Networking     2.985030
# Sports                2.982456
# News                  2.980000
# Lifestyle             2.805556
# Navigation            2.684783
# Book                  2.477679
# Finance               2.432692
# Catalogs              2.100000

# %% [markdown]
# #### Distribution of app ratings
#
# These shall help to see how the app ratings are distributed. This can give an idea of whether the ratings are mostly positive or negative, and if there are any outliers.

# %%
import seaborn as sns

# Create a distribution plot of app ratings
sns.histplot(df['user_rating'], kde=False)

# Add plot labels and title
plt.xlabel('User Rating')
plt.ylabel('Number of Apps')
plt.title('Distribution of App Ratings')

# Show the plot
plt.show()

# %% [markdown]
# #### Price distribution by category
#
# This would help us to identify categories with the highest and lowest app prices, and also show whether the price distribution is skewed or has outliers

# %%
import seaborn as sns

# Create a violin plot of app prices grouped by category
sns.violinplot(x='price', y='prime_genre', data=df)

# Set x-axis label and y-axis label
plt.xlabel('Price')
plt.ylabel('Category')

# Add a title to the plot
plt.title('Price Distribution by Category')

# Show the plot
plt.show()

# %%
df['currency'].unique()
# Out:
# array(['USD'], dtype=object)

# %%
df['currency'].value_counts()
# Out:
# USD    7197
# Name: currency, dtype: int64

# %% [markdown]
# #### Correlation analysis
#
# This would help us to see how different variables are related to each other.

# %%
# Calculate the correlation matrix
corr = df.corr()

# Create a heatmap to visualize the correlation matrix
fig, ax = plt.subplots(figsize=(12, 8), dpi=100)
sns.heatmap(corr, cmap='coolwarm', annot=True, ax=ax)
plt.xticks(rotation=45)

# Add a title to the plot
plt.title('Correlation Matrix')

# Show the plot
plt.show()

# %% [markdown]
# #### Top app categories
#
# This can help to identify popular app categories and target those categories for new app development.

# %%
# Count the number of apps in each category
category_counts = df['prime_genre'].value_counts()

# Sort the results in descending order
category_counts = category_counts.sort_values(ascending=False)

# Print the top 10 categories
print(category_counts.head(10))
# Out:
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Name: prime_genre, dtype: int64

# %% [markdown]
# #### App size by category
#
# This would help to identify categories with the largest and smallest app sizes

# %%
# Group the data by category and calculate the average app size for each category
category_sizes = df.groupby('prime_genre')['size_bytes'].mean()

# Convert the app sizes from bytes to megabytes
category_sizes = category_sizes / (1024 * 1024)

# Sort the results in descending order
category_sizes = category_sizes.sort_values(ascending=False)

# Print the results
print(category_sizes)
# Out:
# prime_genre
# Medical              358.952531
# Games                270.517636
# Education            172.065946
# Book                 170.536639
# Reference            147.974666
# Music                104.556692
# Navigation            98.566518
# Entertainment         96.777650
# Shopping              89.022477
# Health & Fitness      85.932389
# Travel                78.875458
# Social Networking     75.695457
# Sports                75.219701
# Productivity          74.806822
# Finance               74.611530
# Food & Drink          74.000357
# Photo & Video         65.347581
# Business              61.195844
# News                  59.576848
# Lifestyle             59.420078
# Weather               58.595066
# Utilities             51.775036
# Catalogs              47.856934
# Name: size_bytes, dtype: float64
